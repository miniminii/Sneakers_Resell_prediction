# %% [markdown]
# ## SETTING

# %%
import pandas as pd
from glob import glob
import os
import numpy as np
from tqdm import tqdm, tqdm_notebook

import random
import torch
import torch.nn.functional as F

# %%
from google import colab
colab.drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# go to file
os.chdir('/content/drive/MyDrive/김유민/DAB')

# %% [markdown]
# ## 전처리

# %% [markdown]
# 1) duaration = 10번 주기 위해 사이즈별 날짜마다 10번 행 반복
#
# 2) duration기준으로 1일전, 2일전 ,,,, 10일전 mean, min, max 가져오기
#
# 3) targetprice는 각 사이즈의 해당 날짜 내 평균 값. 1개 값으로 고정 !!
#
# 4) 신발사이즈 revise나 240(us.머시기) 같은거 사이즈 숫자기준으로 다 통일 -> 문자로 취급
#
# 5) 날짜 파생변수 만들기 - diff_price, diff_date, year, month, day, weekend
#
# 6) train, test 날짜 제대로 체크 (3/30 ~ 7/2까지)
#
# 7) 신발 정보 매칭하기, size까지해서 범주형으로 취급

# %%
shoe1 = pd.read_csv("/content/drive/Shareddrives/DAB 경진대회/모델링/유민/shoe_cleansing/shoe1.csv")
shoe1.columns = ['date','size','price','name','brand','transaction_t', 'scrab','likes','releaseDate', 'color','releasePrice']
shoe1 = shoe1.sort_values(by=['size','date'])

# %%
data = shoe1.groupby(['size','date']).count() #동일 size내에서 date구분!!
data.sort_values(by = ['size','date']).reset_index(drop=True)
data["todaycount"] =  data["price"] #각 size내 date별로 거래량 카운트
data = data[["todaycount"]]
data = data.reset_index().rename(columns={"index": "id"})

# %%
data
# Out:
#      size        date  todaycount
# 0     220  2022-03-30           1
# 1     220  2022-03-31          15
# 2     220  2022-04-01          21
# 3     220  2022-04-02          11
# 4     220  2022-04-03          15
# ..    ...         ...         ...
# 753   280  2022-05-06           2
# 754   280  2022-05-08           2
# 755   280  2022-05-10           1
# 756   280  2022-06-02           2
# 757   285  2022-04-09           1
#
# [758 rows x 3 columns]

# %%
groups = shoe1.groupby(['size','date'])
groupmean = groups.mean()['price']
groupmin = groups.min()['price']
groupmax = groups.max()['price']

groupdata = pd.DataFrame([groupmean, groupmin, groupmax]).transpose()
groupdata.columns=['mean', 'min', 'max']

# %%
groupdata
# Out:
#                           mean       min       max
# size date
# 220  2022-03-30  162000.000000  162000.0  162000.0
#      2022-03-31  158466.666667  155000.0  160000.0
#      2022-04-01  153476.190476  148000.0  158000.0
#      2022-04-02  160818.181818  159000.0  162000.0
#      2022-04-03  160133.333333  156000.0  162000.0
# ...                        ...       ...       ...
# 280  2022-05-06  173500.000000  170000.0  177000.0
#      2022-05-08  187500.000000  185000.0  190000.0
#      2022-05-10  200000.000000  200000.0  200000.0
#      2022-06-02  187500.000000  165000.0  210000.0
# 285  2022-04-09  140000.000000  140000.0  140000.0
#
# [758 rows x 3 columns]

# %%
data['mean'] = groupdata['mean'].values #합쳐주기
data['min'] = groupdata['min'].values
data['max'] = groupdata['max'].values
data['cumcount'] = [i for i in range(len(data))]
cumtrans = []
for i in range(len(data)):
    if i== 0 : cumtrans.append(data.iloc[i, 2])
    else:
      cumtrans.append(cumtrans[i-1]+data.iloc[i,2])

data['cumtrans'] = cumtrans

# %%
data
# Out:
#      size        date  todaycount           mean       min       max  \
# 0     220  2022-03-30           1  162000.000000  162000.0  162000.0
# 1     220  2022-03-31          15  158466.666667  155000.0  160000.0
# 2     220  2022-04-01          21  153476.190476  148000.0  158000.0
# 3     220  2022-04-02          11  160818.181818  159000.0  162000.0
# 4     220  2022-04-03          15  160133.333333  156000.0  162000.0
# ..    ...         ...         ...            ...       ...       ...
# 753   280  2022-05-06           2  173500.000000  170000.0  177000.0
# 754   280  2022-05-08           2  187500.000000  185000.0  190000.0
# 755   280  2022-05-10           1  200000.000000  200000.0  200000.0
# 756   280  2022-06-02           2  187500.000000  165000.0  210000.0
# 757   285  2022-04-09           1  140000.000000  140000.0  140000.0
#
#      cumcount  cumtrans
# 0           0         1
# 1           1        16
# 2           2        37
# 3           3        48
# 4           4        63
# ..        ...       ...
# 753       753     13137
# 754       754     13139
# 755       755     13140
# 756       756     13142
# 757       757     13143
#
# [758 rows x 8 columns]

# %%
duration = [] #일단 각 행을 10번 늘리기 체크 -> 참고로 나중에 duaration=0인거 빼줘야함

newdata = data.copy()
for i in tqdm(range(len(data))):
    duration.append(0)
    for j in range(10):
      newdata = newdata.append(data.loc[i])
      duration.append(j+1)

newdata = newdata.sort_values(by = ['size','date']).reset_index(drop=True)
newdata['duration'] = duration
newdata #지금 그러면 대략 758행x11번 행 개수만큼 나옴
# Out:
# 100%|██████████| 758/758 [00:31<00:00, 24.21it/s]
#       size        date  todaycount      mean       min       max  cumcount  \
# 0      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 1      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 2      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 3      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 4      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# ...    ...         ...         ...       ...       ...       ...       ...
# 8333   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8334   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8335   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8336   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8337   285  2022-04-09           1  140000.0  140000.0  140000.0       757
#
#       cumtrans  duration
# 0            1         0
# 1            1         1
# 2            1         2
# 3            1         3
# 4            1         4
# ...        ...       ...
# 8333     13143         6
# 8334     13143         7
# 8335     13143         8
# 8336     13143         9
# 8337     13143        10
#
# [8338 rows x 9 columns]

# %%
newdata #지금 그러면 대략 757행x11번 행 개수만큼 나옴
# Out:
#       size        date  todaycount      mean       min       max  cumcount  \
# 0      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 1      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 2      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 3      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 4      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# ...    ...         ...         ...       ...       ...       ...       ...
# 8333   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8334   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8335   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8336   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8337   285  2022-04-09           1  140000.0  140000.0  140000.0       757
#
#       cumtrans  duration
# 0            1         0
# 1            1         1
# 2            1         2
# 3            1         3
# 4            1         4
# ...        ...       ...
# 8333     13143         6
# 8334     13143         7
# 8335     13143         8
# 8336     13143         9
# 8337     13143        10
#
# [8338 rows x 9 columns]

# %%
#targetprice는 신발별 해당 날짜의 평균으로 고정
#한 날짜별로 (target)price가 하나여야지, 여러개면 말이 안됨..
newdata['targetprice'] = newdata['mean']

# %%
#해당 사이즈&날짜에서 1,2,3,,10(=duration)일 전 mean, min, max값 가져오기
duration = []
lastmean = []
lastmin = []
lastmax = []

newdata = data.copy()
for i in tqdm(range(len(data))):
    duration.append(0)
    lastmean.append(data.iloc[i,3])
    lastmin.append(data.iloc[i,4])
    lastmax.append(data.iloc[i,5])
    for j in range(10):  
      newdata = newdata.append(data.loc[i])
      duration.append(j+1)
      try:
        lastmean.append(data.iloc[i-j-1,3])  #1,2,3,,, 전 mean값 가져오기
        lastmin.append(data.iloc[i-j-1,4])
        lastmax.append(data.iloc[i-j-1,5])
      except:
        lastmean.append(-1)
        lastmin.append(-1)
        lastmax.append(-1)

newdata = newdata.sort_values(by = ['size','date']).reset_index(drop=True)
newdata['duration'] = duration
newdata['lastmean'] = lastmean
newdata['lastmin'] = lastmin
newdata['lastmax'] = lastmax

newdata
# Out:
# 100%|██████████| 758/758 [00:31<00:00, 23.98it/s]
#       size        date  todaycount      mean       min       max  cumcount  \
# 0      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 1      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 2      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 3      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# 4      220  2022-03-30           1  162000.0  162000.0  162000.0         0
# ...    ...         ...         ...       ...       ...       ...       ...
# 8333   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8334   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8335   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8336   285  2022-04-09           1  140000.0  140000.0  140000.0       757
# 8337   285  2022-04-09           1  140000.0  140000.0  140000.0       757
#
#       cumtrans  duration  lastmean   lastmin   lastmax
# 0            1         0  162000.0  162000.0  162000.0
# 1            1         1  140000.0  140000.0  140000.0
# 2            1         2  187500.0  165000.0  210000.0
# 3            1         3  200000.0  200000.0  200000.0
# 4            1         4  187500.0  185000.0  190000.0
# ...        ...       ...       ...       ...       ...
# 8333     13143         6  190000.0  190000.0  190000.0
# 8334     13143         7  180000.0  180000.0  180000.0
# 8335     13143         8  179000.0  179000.0  179000.0
# 8336     13143         9  179000.0  179000.0  179000.0
# 8337     13143        10  175000.0  175000.0  175000.0
#
# [8338 rows x 12 columns]

# %%
#이제 1) 초반날짜라 2,3,4,,10일 전만큼 참고할 게 없는 행 2) duartion이 0 인 행 => 삭제

# %%
index1 = newdata[(newdata['date'] == '2022-03-30') & ((newdata['duration'] ==1) |(newdata['duration'] ==2) |(newdata['duration'] ==3)|(newdata['duration'] ==4)|(newdata['duration'] ==5)|(newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index2 = newdata[(newdata['date'] == '2022-03-31') & ((newdata['duration'] ==2) |(newdata['duration'] ==3)|(newdata['duration'] ==4)|(newdata['duration'] ==5)|(newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index3 = newdata[(newdata['date'] == '2022-04-01') & ((newdata['duration'] ==3)|(newdata['duration'] ==4)|(newdata['duration'] ==5)|(newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index4 = newdata[(newdata['date'] == '2022-04-02') & ((newdata['duration'] ==4)|(newdata['duration'] ==5)|(newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index5 = newdata[(newdata['date'] == '2022-04-03') & ((newdata['duration'] ==5)|(newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index6 = newdata[(newdata['date'] == '2022-04-04') & ((newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index7 = newdata[(newdata['date'] == '2022-04-05') & ((newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index8 = newdata[(newdata['date'] == '2022-04-06') & ((newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index9 = newdata[(newdata['date'] == '2022-04-07') & ((newdata['duration'] ==9)|(newdata['duration'] ==10))]
index10 = newdata[(newdata['date'] == '2022-04-08') & (newdata['duration'] ==10)]

# %%
newdata = newdata.drop(index1.index)
newdata = newdata.drop(index2.index)
newdata = newdata.drop(index3.index)
newdata = newdata.drop(index4.index)
newdata = newdata.drop(index5.index)
newdata = newdata.drop(index6.index)
newdata = newdata.drop(index7.index)
newdata = newdata.drop(index8.index)
newdata = newdata.drop(index9.index)
newdata = newdata.drop(index10.index).reset_index(drop=True)

# %%
newdata = newdata.loc[newdata['duration']!=0,:]
newdata = newdata.reset_index(drop=True)
newdata
# Out:
#       size        date  todaycount           mean       min       max  \
# 0      220  2022-03-31          15  158466.666667  155000.0  160000.0
# 1      220  2022-04-01          21  153476.190476  148000.0  158000.0
# 2      220  2022-04-01          21  153476.190476  148000.0  158000.0
# 3      220  2022-04-02          11  160818.181818  159000.0  162000.0
# 4      220  2022-04-02          11  160818.181818  159000.0  162000.0
# ...    ...         ...         ...            ...       ...       ...
# 7285   285  2022-04-09           1  140000.000000  140000.0  140000.0
# 7286   285  2022-04-09           1  140000.000000  140000.0  140000.0
# 7287   285  2022-04-09           1  140000.000000  140000.0  140000.0
# 7288   285  2022-04-09           1  140000.000000  140000.0  140000.0
# 7289   285  2022-04-09           1  140000.000000  140000.0  140000.0
#
#       cumcount  cumtrans  duration       lastmean   lastmin   lastmax  \
# 0            1        16         1  162000.000000  162000.0  162000.0
# 1            2        37         1  158466.666667  155000.0  160000.0
# 2            2        37         2  162000.000000  162000.0  162000.0
# 3            3        48         1  153476.190476  148000.0  158000.0
# 4            3        48         2  158466.666667  155000.0  160000.0
# ...        ...       ...       ...            ...       ...       ...
# 7285       757     13143         6  190000.000000  190000.0  190000.0
# 7286       757     13143         7  180000.000000  180000.0  180000.0
# 7287       757     13143         8  179000.000000  179000.0  179000.0
# 7288       757     13143         9  179000.000000  179000.0  179000.0
# 7289       757     13143        10  175000.000000  175000.0  175000.0
#
#         targetprice
# 0     158466.666667
# 1     153476.190476
# 2     153476.190476
# 3     160818.181818
# 4     160818.181818
# ...             ...
# 7285  140000.000000
# 7286  140000.000000
# 7287  140000.000000
# 7288  140000.000000
# 7289  140000.000000
#
# [7290 rows x 13 columns]

# %%
# 기존에 mean, min, max열 삭제해주기
newdata['targetprice'] = newdata['mean'] 
newdata = newdata.drop(['mean','min','max'], axis=1)

# %%
#스니커즈 정보 불러오기
newdata['name'] = shoe1['name'][0]
newdata['brand'] = shoe1['brand'][0]
newdata['transaction_t'] = shoe1['transaction_t'][0]
newdata['scrab'] = shoe1['likes'][0]
newdata['color'] = shoe1['color'][0]
newdata['releaseDate'] = shoe1['releaseDate'][0]
newdata['releasePrice'] = shoe1['releasePrice'][0]
#날짜 파생변수 만들기 - diff_price, diff_date, year, month, day, weekend
newdata['diff_price'] = newdata['lastmean'] - newdata['releasePrice']
newdata['date'] = pd.to_datetime(newdata['date'], format = '%Y-%m-%d')
newdata['releaseDate'] = shoe1['releaseDate'][0]
newdata['releaseDate'] = pd.to_datetime(newdata['releaseDate'], format = '%Y-%m-%d')
newdata['diff_date'] = newdata['date']-newdata['releaseDate']
newdata['diff_date'] =newdata['diff_date'].dt.days 
newdata['date'] = newdata['date'].astype(str)
newdata[['year','month', 'day']] = newdata['date'].str.split('-', expand=True)
newdata['weekend'] = pd.to_datetime(newdata['date'],yearfirst=True).dt.dayofweek>4

newdata['month']=newdata['month'].astype(int)
newdata['day']=newdata['day'].astype(int)

# %%
new1 = newdata.copy()

# %%
new1
# Out:
#       size        date  todaycount  cumcount  cumtrans  duration  \
# 0      220  2022-03-31          15         1        16         1
# 1      220  2022-04-01          21         2        37         1
# 2      220  2022-04-01          21         2        37         2
# 3      220  2022-04-02          11         3        48         1
# 4      220  2022-04-02          11         3        48         2
# ...    ...         ...         ...       ...       ...       ...
# 7285   285  2022-04-09           1       757     13143         6
# 7286   285  2022-04-09           1       757     13143         7
# 7287   285  2022-04-09           1       757     13143         8
# 7288   285  2022-04-09           1       757     13143         9
# 7289   285  2022-04-09           1       757     13143        10
#
#            lastmean   lastmin   lastmax    targetprice  ... scrab  color  \
# 0     162000.000000  162000.0  162000.0  158466.666667  ...   880  WHITE
# 1     158466.666667  155000.0  160000.0  153476.190476  ...   880  WHITE
# 2     162000.000000  162000.0  162000.0  153476.190476  ...   880  WHITE
# 3     153476.190476  148000.0  158000.0  160818.181818  ...   880  WHITE
# 4     158466.666667  155000.0  160000.0  160818.181818  ...   880  WHITE
# ...             ...       ...       ...            ...  ...   ...    ...
# 7285  190000.000000  190000.0  190000.0  140000.000000  ...   880  WHITE
# 7286  180000.000000  180000.0  180000.0  140000.000000  ...   880  WHITE
# 7287  179000.000000  179000.0  179000.0  140000.000000  ...   880  WHITE
# 7288  179000.000000  179000.0  179000.0  140000.000000  ...   880  WHITE
# 7289  175000.000000  175000.0  175000.0  140000.000000  ...   880  WHITE
#
#       releaseDate  releasePrice    diff_price diff_date  year  month  day  \
# 0      2019-01-02        129000  33000.000000      1184  2022     03   31
# 1      2019-01-02        129000  29466.666667      1185  2022     04   01
# 2      2019-01-02        129000  33000.000000      1185  2022     04   01
# 3      2019-01-02        129000  24476.190476      1186  2022     04   02
# 4      2019-01-02        129000  29466.666667      1186  2022     04   02
# ...           ...           ...           ...       ...   ...    ...  ...
# 7285   2019-01-02        129000  61000.000000      1193  2022     04   09
# 7286   2019-01-02        129000  51000.000000      1193  2022     04   09
# 7287   2019-01-02        129000  50000.000000      1193  2022     04   09
# 7288   2019-01-02        129000  50000.000000      1193  2022     04   09
# 7289   2019-01-02        129000  46000.000000      1193  2022     04   09
#
#      weekend
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
# ...      ...
# 7285    True
# 7286    True
# 7287    True
# 7288    True
# 7289    True
#
# [7290 rows x 23 columns]

# %% [markdown]
# ### 반복

# %%
shoe1 = pd.read_csv("/content/drive/Shareddrives/DAB 경진대회/모델링/유민/shoe_cleansing/shoe13.csv")
shoe1.columns = ['date','size','price','name','brand','transaction_t', 'scrab','likes','releaseDate', 'color','releasePrice']
shoe1 = shoe1.sort_values(by=['size','date'])

# %%
data = shoe1.groupby(['size','date']).count() #동일 size내에서 date구분!!
data.sort_values(by = ['size','date']).reset_index(drop=True)
data["todaycount"] =  data["price"] #각 size내 date별로 거래량 카운트
data = data[["todaycount"]]
data = data.reset_index().rename(columns={"index": "id"})

# %%
groups = shoe1.groupby(['size','date'])
groupmean = groups.mean()['price']
groupmin = groups.min()['price']
groupmax = groups.max()['price']

groupdata = pd.DataFrame([groupmean, groupmin, groupmax]).transpose()
groupdata.columns=['mean', 'min', 'max']

# %%
data['mean'] = groupdata['mean'].values #합쳐주기
data['min'] = groupdata['min'].values
data['max'] = groupdata['max'].values
data['cumcount'] = [i for i in range(len(data))]
cumtrans = []
for i in range(len(data)):
    if i== 0 : cumtrans.append(data.iloc[i, 2])
    else:
      cumtrans.append(cumtrans[i-1]+data.iloc[i,2])

data['cumtrans'] = cumtrans

# %%
#해당 날짜에서 1,2,3,,10(=duration)일 전 mean, min, max값 가져오기
duration = []
lastmean = []
lastmin = []
lastmax = []

newdata = data.copy()
for i in tqdm(range(len(data))):
    duration.append(0)
    lastmean.append(data.iloc[i,3])
    lastmin.append(data.iloc[i,4])
    lastmax.append(data.iloc[i,5])
    for j in range(10):  
      newdata = newdata.append(data.loc[i])
      duration.append(j+1)
      try:
        lastmean.append(data.iloc[i-j-1,3])  #1,2,3,,, 전 mean값 가져오기
        lastmin.append(data.iloc[i-j-1,4])
        lastmax.append(data.iloc[i-j-1,5])
      except:
        lastmean.append(-1)
        lastmin.append(-1)
        lastmax.append(-1)

newdata = newdata.sort_values(by = ['size','date']).reset_index(drop=True)
newdata['duration'] = duration
newdata['lastmean'] = lastmean
newdata['lastmin'] = lastmin
newdata['lastmax'] = lastmax

newdata
# Out:
# 100%|██████████| 120/120 [00:04<00:00, 25.03it/s]
#       size        date  todaycount      mean       min       max  cumcount  \
# 0      225  2022-06-30           1  650000.0  650000.0  650000.0         0
# 1      225  2022-06-30           1  650000.0  650000.0  650000.0         0
# 2      225  2022-06-30           1  650000.0  650000.0  650000.0         0
# 3      225  2022-06-30           1  650000.0  650000.0  650000.0         0
# 4      225  2022-06-30           1  650000.0  650000.0  650000.0         0
# ...    ...         ...         ...       ...       ...       ...       ...
# 1315   305  2022-07-01           1  790000.0  790000.0  790000.0       119
# 1316   305  2022-07-01           1  790000.0  790000.0  790000.0       119
# 1317   305  2022-07-01           1  790000.0  790000.0  790000.0       119
# 1318   305  2022-07-01           1  790000.0  790000.0  790000.0       119
# 1319   305  2022-07-01           1  790000.0  790000.0  790000.0       119
#
#       cumtrans  duration      lastmean    lastmin    lastmax
# 0            1         0  6.500000e+05   650000.0   650000.0
# 1            1         1  7.900000e+05   790000.0   790000.0
# 2            1         2  1.009000e+06  1009000.0  1009000.0
# 3            1         3  8.900000e+05   890000.0   890000.0
# 4            1         4  9.800000e+05   980000.0   980000.0
# ...        ...       ...           ...        ...        ...
# 1315       414         6  9.000000e+05   900000.0   900000.0
# 1316       414         7  8.350000e+05   810000.0   860000.0
# 1317       414         8  9.385000e+05   927000.0   950000.0
# 1318       414         9  9.635000e+05   910000.0  1090000.0
# 1319       414        10  9.563333e+05   920000.0   979000.0
#
# [1320 rows x 12 columns]

# %%
index1 = newdata[(newdata['date'] == '2022-03-30') & ((newdata['duration'] ==1) |(newdata['duration'] ==2) |(newdata['duration'] ==3)|(newdata['duration'] ==4)|(newdata['duration'] ==5)|(newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index2 = newdata[(newdata['date'] == '2022-03-31') & ((newdata['duration'] ==2) |(newdata['duration'] ==3)|(newdata['duration'] ==4)|(newdata['duration'] ==5)|(newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index3 = newdata[(newdata['date'] == '2022-04-01') & ((newdata['duration'] ==3)|(newdata['duration'] ==4)|(newdata['duration'] ==5)|(newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index4 = newdata[(newdata['date'] == '2022-04-02') & ((newdata['duration'] ==4)|(newdata['duration'] ==5)|(newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index5 = newdata[(newdata['date'] == '2022-04-03') & ((newdata['duration'] ==5)|(newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index6 = newdata[(newdata['date'] == '2022-04-04') & ((newdata['duration'] ==6)|(newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index7 = newdata[(newdata['date'] == '2022-04-05') & ((newdata['duration'] ==7)|(newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index8 = newdata[(newdata['date'] == '2022-04-06') & ((newdata['duration'] ==8)|(newdata['duration'] ==9)|(newdata['duration'] ==10))]
index9 = newdata[(newdata['date'] == '2022-04-07') & ((newdata['duration'] ==9)|(newdata['duration'] ==10))]
index10 = newdata[(newdata['date'] == '2022-04-08') & (newdata['duration'] ==10)]

# %%
newdata = newdata.drop(index1.index)
newdata = newdata.drop(index2.index)
newdata = newdata.drop(index3.index)
newdata = newdata.drop(index4.index)
newdata = newdata.drop(index5.index)
newdata = newdata.drop(index6.index)
newdata = newdata.drop(index7.index)
newdata = newdata.drop(index8.index)
newdata = newdata.drop(index9.index)
newdata = newdata.drop(index10.index).reset_index(drop=True)

# %%
newdata = newdata.loc[newdata['duration']!=0,:]
newdata = newdata.reset_index(drop=True)
newdata
# Out:
#       size        date  todaycount      mean       min       max  cumcount  \
# 0      225  2022-06-30           1  650000.0  650000.0  650000.0         0
# 1      225  2022-06-30           1  650000.0  650000.0  650000.0         0
# 2      225  2022-06-30           1  650000.0  650000.0  650000.0         0
# 3      225  2022-06-30           1  650000.0  650000.0  650000.0         0
# 4      225  2022-06-30           1  650000.0  650000.0  650000.0         0
# ...    ...         ...         ...       ...       ...       ...       ...
# 1195   305  2022-07-01           1  790000.0  790000.0  790000.0       119
# 1196   305  2022-07-01           1  790000.0  790000.0  790000.0       119
# 1197   305  2022-07-01           1  790000.0  790000.0  790000.0       119
# 1198   305  2022-07-01           1  790000.0  790000.0  790000.0       119
# 1199   305  2022-07-01           1  790000.0  790000.0  790000.0       119
#
#       cumtrans  duration      lastmean    lastmin    lastmax
# 0            1         1  7.900000e+05   790000.0   790000.0
# 1            1         2  1.009000e+06  1009000.0  1009000.0
# 2            1         3  8.900000e+05   890000.0   890000.0
# 3            1         4  9.800000e+05   980000.0   980000.0
# 4            1         5  8.750000e+05   850000.0   900000.0
# ...        ...       ...           ...        ...        ...
# 1195       414         6  9.000000e+05   900000.0   900000.0
# 1196       414         7  8.350000e+05   810000.0   860000.0
# 1197       414         8  9.385000e+05   927000.0   950000.0
# 1198       414         9  9.635000e+05   910000.0  1090000.0
# 1199       414        10  9.563333e+05   920000.0   979000.0
#
# [1200 rows x 12 columns]

# %%
# 기존에 mean, min, max열 삭제해주기
newdata['targetprice'] = newdata['mean'] 
newdata = newdata.drop(['mean','min','max'], axis=1)

# %%
#스니커즈 정보 불러오기
newdata['name'] = shoe1['name'][0]
newdata['brand'] = shoe1['brand'][0]
newdata['transaction_t'] = shoe1['transaction_t'][0]
newdata['scrab'] = shoe1['likes'][0]
newdata['color'] = shoe1['color'][0]
newdata['releaseDate'] = shoe1['releaseDate'][0]
newdata['releasePrice'] = shoe1['releasePrice'][0]
#newdata['releasePrice'] = newdata['releasePrice'].str.replace(",", "", )
#newdata['releasePrice'] = newdata['releasePrice'].astype(int)

#날짜 파생변수 만들기 - diff_price, diff_date, year, month, day, weekend
newdata['diff_price'] = newdata['lastmean'] - newdata['releasePrice']
newdata['date'] = pd.to_datetime(newdata['date'], format = '%Y-%m-%d')
newdata['releaseDate'] = shoe1['releaseDate'][0]
newdata['releaseDate'] = pd.to_datetime(newdata['releaseDate'], format = '%Y-%m-%d')
newdata['diff_date'] = newdata['date']-newdata['releaseDate']
newdata['diff_date'] =newdata['diff_date'].dt.days 
newdata['date'] = newdata['date'].astype(str)
newdata[['year','month', 'day']] = newdata['date'].str.split('-', expand=True)
newdata['weekend'] = pd.to_datetime(newdata['date'],yearfirst=True).dt.dayofweek>4

# %%
new13 = newdata.copy()

# %%
new11

# %%
combine = pd.concat([new1,new2,new3, new4,new5,new6,new7,new8,new9,new10,new11,new12,new13], ignore_index=True)

# %%
combine
# Out:
#        size        date  todaycount  cumcount  cumtrans  duration  \
# 0       220  2022-03-31          15         1        16         1
# 1       220  2022-04-01          21         2        37         1
# 2       220  2022-04-01          21         2        37         2
# 3       220  2022-04-02          11         3        48         1
# 4       220  2022-04-02          11         3        48         2
# ...     ...         ...         ...       ...       ...       ...
# 89611   305  2022-07-01           1       119       414         6
# 89612   305  2022-07-01           1       119       414         7
# 89613   305  2022-07-01           1       119       414         8
# 89614   305  2022-07-01           1       119       414         9
# 89615   305  2022-07-01           1       119       414        10
#
#             lastmean   lastmin    lastmax    targetprice  ... scrab  \
# 0      162000.000000  162000.0   162000.0  158466.666667  ...   880
# 1      158466.666667  155000.0   160000.0  153476.190476  ...   880
# 2      162000.000000  162000.0   162000.0  153476.190476  ...   880
# 3      153476.190476  148000.0   158000.0  160818.181818  ...   880
# 4      158466.666667  155000.0   160000.0  160818.181818  ...   880
# ...              ...       ...        ...            ...  ...   ...
# 89611  900000.000000  900000.0   900000.0  790000.000000  ...   141
# 89612  835000.000000  810000.0   860000.0  790000.000000  ...   141
# 89613  938500.000000  927000.0   950000.0  790000.000000  ...   141
# 89614  963500.000000  910000.0  1090000.0  790000.000000  ...   141
# 89615  956333.333333  920000.0   979000.0  790000.000000  ...   141
#
#                               color  releaseDate  releasePrice     diff_price  \
# 0                             WHITE   2019-01-02        129000   33000.000000
# 1                             WHITE   2019-01-02        129000   29466.666667
# 2                             WHITE   2019-01-02        129000   33000.000000
# 3                             WHITE   2019-01-02        129000   24476.190476
# 4                             WHITE   2019-01-02        129000   29466.666667
# ...                             ...          ...           ...            ...
# 89611  LIGHT CREAM/WHITE-LIGHT BONE   2022-06-10        145000  755000.000000
# 89612  LIGHT CREAM/WHITE-LIGHT BONE   2022-06-10        145000  690000.000000
# 89613  LIGHT CREAM/WHITE-LIGHT BONE   2022-06-10        145000  793500.000000
# 89614  LIGHT CREAM/WHITE-LIGHT BONE   2022-06-10        145000  818500.000000
# 89615  LIGHT CREAM/WHITE-LIGHT BONE   2022-06-10        145000  811333.333333
#
#       diff_date  year  month  day weekend
# 0          1184  2022     03   31   False
# 1          1185  2022     04   01   False
# 2          1185  2022     04   01   False
# 3          1186  2022     04   02    True
# 4          1186  2022     04   02    True
# ...         ...   ...    ...  ...     ...
# 89611        21  2022     07   01   False
# 89612        21  2022     07   01   False
# 89613        21  2022     07   01   False
# 89614        21  2022     07   01   False
# 89615        21  2022     07   01   False
#
# [89616 rows x 23 columns]

# %%
combine.to_csv("/content/drive/Shareddrives/DAB 경진대회/모델링/유민/combine_revise.csv", index=False)

# %%
combine_10 = pd.concat([new1,new2,new3, new4,new5,new6,new7,new8,new9,new10], ignore_index=True)

# %%
combine_10.to_csv("/content/drive/Shareddrives/DAB 경진대회/모델링/유민/combine_revise10.csv", index=False)

# %% [markdown]
# ## **train/val/test 분리**

# %%
combine = pd.read_csv('/content/drive/Shareddrives/DAB 경진대회/모델링/유민/combine_revise10.csv')

# %%
from datetime import datetime, timedelta
test = []
for i in range(len(combine)):
  future = datetime.strptime(combine.iloc[i,1],"%Y-%m-%d") + timedelta(int(combine.iloc[i,5]))
  if future > datetime(2022,6,25):
    test.append(1)
  else:
    test.append(0)

# %%
combine['test'] = test
combine
# Out:
#        size        date  todaycount  cumcount  cumtrans  duration  \
# 0       220  2022-03-31          15         1        16         1
# 1       220  2022-04-01          21         2        37         1
# 2       220  2022-04-01          21         2        37         2
# 3       220  2022-04-02          11         3        48         1
# 4       220  2022-04-02          11         3        48         2
# ...     ...         ...         ...       ...       ...       ...
# 77167   310  2022-06-25           1      1084      7554         6
# 77168   310  2022-06-25           1      1084      7554         7
# 77169   310  2022-06-25           1      1084      7554         8
# 77170   310  2022-06-25           1      1084      7554         9
# 77171   310  2022-06-25           1      1084      7554        10
#
#             lastmean   lastmin   lastmax    targetprice  ...  \
# 0      162000.000000  162000.0  162000.0  158466.666667  ...
# 1      158466.666667  155000.0  160000.0  153476.190476  ...
# 2      162000.000000  162000.0  162000.0  153476.190476  ...
# 3      153476.190476  148000.0  158000.0  160818.181818  ...
# 4      158466.666667  155000.0  160000.0  160818.181818  ...
# ...              ...       ...       ...            ...  ...
# 77167  225000.000000  220000.0  230000.0  233000.000000  ...
# 77168  246500.000000  243000.0  250000.0  233000.000000  ...
# 77169  269000.000000  269000.0  269000.0  233000.000000  ...
# 77170  275000.000000  275000.0  275000.0  233000.000000  ...
# 77171  255000.000000  255000.0  255000.0  233000.000000  ...
#
#                      color releaseDate  releasePrice     diff_price diff_date  \
# 0                    WHITE  2019-01-02        129000   33000.000000      1184
# 1                    WHITE  2019-01-02        129000   29466.666667      1185
# 2                    WHITE  2019-01-02        129000   33000.000000      1185
# 3                    WHITE  2019-01-02        129000   24476.190476      1186
# 4                    WHITE  2019-01-02        129000   29466.666667      1186
# ...                    ...         ...           ...            ...       ...
# 77167  SAIL/STARFISH-BLACK  2022-01-18        129000   96000.000000       158
# 77168  SAIL/STARFISH-BLACK  2022-01-18        129000  117500.000000       158
# 77169  SAIL/STARFISH-BLACK  2022-01-18        129000  140000.000000       158
# 77170  SAIL/STARFISH-BLACK  2022-01-18        129000  146000.000000       158
# 77171  SAIL/STARFISH-BLACK  2022-01-18        129000  126000.000000       158
#
#        year  month  day  weekend  test
# 0      2022      3   31    False     0
# 1      2022      4    1    False     0
# 2      2022      4    1    False     0
# 3      2022      4    2     True     0
# 4      2022      4    2     True     0
# ...     ...    ...  ...      ...   ...
# 77167  2022      6   25     True     1
# 77168  2022      6   25     True     1
# 77169  2022      6   25     True     1
# 77170  2022      6   25     True     1
# 77171  2022      6   25     True     1
#
# [77172 rows x 24 columns]

# %%
combine.columns
# Out:
# Index(['size', 'date', 'todaycount', 'cumcount', 'cumtrans', 'duration',
#        'lastmean', 'lastmin', 'lastmax', 'targetprice', 'name', 'brand',
#        'transaction_t', 'scrab', 'color', 'releaseDate', 'releasePrice',
#        'diff_price', 'diff_date', 'year', 'month', 'day', 'weekend', 'test'],
#       dtype='object')

# %%
combine['month']=combine['month'].astype(int)
combine['day']=combine['day'].astype(int)

# %%
df_train = combine.loc[combine['test']==0].reset_index(drop=True)
df_val  = combine.loc[combine['test']==1].reset_index(drop=True)

# %% [markdown]
# #### **범주형 만들기 - size, name, brand, color**

# %%
df_train
# Out:
#        size        date  todaycount  cumcount  cumtrans  duration  \
# 0       220  2022-03-31          15         1        16         1
# 1       220  2022-04-01          21         2        37         1
# 2       220  2022-04-01          21         2        37         2
# 3       220  2022-04-02          11         3        48         1
# 4       220  2022-04-02          11         3        48         2
# ...     ...         ...         ...       ...       ...       ...
# 64466   310  2022-06-09           1      1083      7553         6
# 64467   310  2022-06-09           1      1083      7553         7
# 64468   310  2022-06-09           1      1083      7553         8
# 64469   310  2022-06-09           1      1083      7553         9
# 64470   310  2022-06-09           1      1083      7553        10
#
#             lastmean   lastmin   lastmax    targetprice  ...  \
# 0      162000.000000  162000.0  162000.0  158466.666667  ...
# 1      158466.666667  155000.0  160000.0  153476.190476  ...
# 2      162000.000000  162000.0  162000.0  153476.190476  ...
# 3      153476.190476  148000.0  158000.0  160818.181818  ...
# 4      158466.666667  155000.0  160000.0  160818.181818  ...
# ...              ...       ...       ...            ...  ...
# 64466  246500.000000  243000.0  250000.0  206000.000000  ...
# 64467  269000.000000  269000.0  269000.0  206000.000000  ...
# 64468  275000.000000  275000.0  275000.0  206000.000000  ...
# 64469  255000.000000  255000.0  255000.0  206000.000000  ...
# 64470  289000.000000  289000.0  289000.0  206000.000000  ...
#
#                      color releaseDate  releasePrice     diff_price diff_date  \
# 0                    WHITE  2019-01-02        129000   33000.000000      1184
# 1                    WHITE  2019-01-02        129000   29466.666667      1185
# 2                    WHITE  2019-01-02        129000   33000.000000      1185
# 3                    WHITE  2019-01-02        129000   24476.190476      1186
# 4                    WHITE  2019-01-02        129000   29466.666667      1186
# ...                    ...         ...           ...            ...       ...
# 64466  SAIL/STARFISH-BLACK  2022-01-18        129000  117500.000000       142
# 64467  SAIL/STARFISH-BLACK  2022-01-18        129000  140000.000000       142
# 64468  SAIL/STARFISH-BLACK  2022-01-18        129000  146000.000000       142
# 64469  SAIL/STARFISH-BLACK  2022-01-18        129000  126000.000000       142
# 64470  SAIL/STARFISH-BLACK  2022-01-18        129000  160000.000000       142
#
#        year  month  day  weekend  test
# 0      2022      3   31    False     0
# 1      2022      4    1    False     0
# 2      2022      4    1    False     0
# 3      2022      4    2     True     0
# 4      2022      4    2     True     0
# ...     ...    ...  ...      ...   ...
# 64466  2022      6    9    False     0
# 64467  2022      6    9    False     0
# 64468  2022      6    9    False     0
# 64469  2022      6    9    False     0
# 64470  2022      6    9    False     0
#
# [64471 rows x 24 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)

object_cols = ['size', 'name','brand','color']
OH_cols_train = pd.DataFrame(OH_encoder.fit_transform(df_train[object_cols]))
OH_cols_valid = pd.DataFrame(OH_encoder.transform(df_val[object_cols]))

# One-hot encoding removed index; put it back
OH_cols_train.index = df_train.index
OH_cols_valid.index = df_val.index

# %%
OH_cols_train.columns = OH_encoder.get_feature_names(object_cols)
OH_cols_valid.columns = OH_encoder.get_feature_names(object_cols)

# Remove categorical columns (will replace with one-hot encoding)
num_X_train = df_train.drop(object_cols, axis=1)
num_X_valid = df_val.drop(object_cols, axis=1)

# Add one-hot encoded columns to numerical features
train_df = pd.concat([num_X_train, OH_cols_train], axis=1)
val_df= pd.concat([num_X_valid, OH_cols_valid], axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
train_df

# %% [markdown]
# ## 모델링
#
# - 제품 전체로 같이 보고 변수들로 예측하는것도 성능 꽤좋음

# %% [markdown]
# ###xgb1

# %%
train_df.columns
# Out:
# Index(['date', 'todaycount', 'cumcount', 'cumtrans', 'duration', 'lastmean',
#        'lastmin', 'lastmax', 'targetprice', 'transaction_t', 'scrab',
#        'releaseDate', 'releasePrice', 'diff_price', 'diff_date', 'year',
#        'month', 'day', 'weekend', 'test', 'size_215', 'size_220', 'size_225',
#        'size_230', 'size_235', 'size_240', 'size_245', 'size_250', 'size_255',
#        'size_260', 'size_265', 'size_270', 'size_275', 'size_280', 'size_285',
#        'size_290', 'size_295', 'size_300', 'size_305', 'size_310', 'size_315',
#        'size_320', 'size_330', 'name_(W) Nike Air Force 1 '07 Low White',
#        'name_Adidas Yeezy Foam RNNR Onyx', 'name_Jordan 1 Low Golf Wolf Grey',
#        'name_Jordan 1 Mid Light Smoke Gray Anthracite',
#        'name_Jordan 1 Retro High OG Black Mocha',
#        'name_New Balance 992 Made in USA Grey - D Standard',
#        'name_New Balance 993 Made in USA Grey - D Standard',
#        'name_Nike Air Force 1 '07 Low White', 'name_Nike Dunk Low Black',
#        'name_Nike Dunk Low Retro PRM Halloween', 'brand_Adidas',
#        'brand_Jordan', 'brand_New Balance', 'brand_Nike', 'color_GREY',
#        'color_GREY/WHITE', 'color_LIGHT SMOKE GREY/WHITE-ANTHRACITE',
#        'color_ONYX', 'color_SAIL/DARK MOCHA-BLACK-BLACK',
#        'color_SAIL/STARFISH-BLACK', 'color_WHITE', 'color_WHITE/BLACK',
#        'color_WOLF GREY/BLACK-PHOTON DUST-WHITE'],
#       dtype='object')

# %%
#xgb_features =  ['발매가', 'date_diff', '거래 사이즈_230', '거래 사이즈_240(US 6)', '거래 사이즈_245','거래 사이즈_250', '거래 사이즈_255', '거래 사이즈_260', '거래 사이즈_270', '거래 사이즈_280']              
xgb_train = train_df.drop(['date', 'targetprice','releaseDate','test', 'year'], axis=1) #일단 전부 다
xgb_val = val_df.drop(['date', 'targetprice','releaseDate','test', 'year'], axis=1)

# %%
train_y = train_df['targetprice']
val_y = val_df['targetprice']

# %%
params = {
    'learning_rate': 0.02,
    'objective': 'reg:squarederror',
    'eval_metric':'mae', 
    'seed':42
}

# %%
import xgboost as xgb

d_train = xgb.DMatrix(data=xgb_train, label = train_y)
d_val = xgb.DMatrix(data=xgb_val, label = val_y)
wlist = [(d_train, 'train'), (d_val,'eval')]

xgb_model = xgb.train(params, d_train, 5000, evals=wlist, verbose_eval=100, early_stopping_rounds=100)
# Out:
# [0]	train-mae:302933	eval-mae:274352
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# [100]	train-mae:40482.8	eval-mae:36090.6
# [200]	train-mae:8982.54	eval-mae:13746.2
# [300]	train-mae:6701.87	eval-mae:12123.8
# [400]	train-mae:6324.38	eval-mae:11878
# [500]	train-mae:5995.87	eval-mae:11731.1
# [600]	train-mae:5709.05	eval-mae:11559
# [700]	train-mae:5434.11	eval-mae:11450.7
# [800]	train-mae:5182.79	eval-mae:11303.1
# [900]	train-mae:4967.98	eval-mae:11232.6
# [1000]	train-mae:4778.08	eval-mae:11152.1
# [1100]	train-mae:4610.46	eval-mae:11070.6
# [1200]	train-mae:4466.15	eval-mae:10994.6
# [1300]	train-mae:4333.66	eval-mae:10940.8
# [1400]	train-mae:4197.26	eval-mae:10861.3
# [1500]	train-mae:4071.48	eval-mae:10809.8
# [1600]	train-mae:3958.66	eval-mae:10766.8
# [1700]	train-mae:3844.81	eval-mae:10697.4
# [1800]	train-mae:3735.42	eval-mae:10641.2
# [1900]	train-mae:3638.52	eval-mae:10614
# [2000]	train-mae:3557.32	eval-mae:10585.4
# [2100]	train-mae:3476.91	eval-mae:10547.1
# [2200]	train-mae:3400.14	eval-mae:10499.4
# [2300]	train-mae:3330.53	eval-mae:10469.2
# [2400]	train-mae:3258.06	eval-mae:10439.6
# [2500]	train-mae:3184.54	eval-mae:10393.9
# [2600]	train-mae:3121.47	eval-mae:10376.4
# [2700]	train-mae:3061.26	eval-mae:10345.9
# [2800]	train-mae:3002.57	eval-mae:10259.5
# [2900]	train-mae:2935.6	eval-mae:10200.2
# [3000]	train-mae:2873.29	eval-mae:10168
# [3100]	train-mae:2820.64	eval-mae:10139.5
# [3200]	train-mae:2760.9	eval-mae:10089.3
# [3300]	train-mae:2705.15	eval-mae:10053
# [3400]	train-mae:2651.18	eval-mae:10032.6
# [3500]	train-mae:2604.76	eval-mae:10018.1
# [3600]	train-mae:2566.62	eval-mae:9987.57
# [3700]	train-mae:2523.5	eval-mae:9971.69
# [3800]	train-mae:2484.82	eval-mae:9950.94
# [3900]	train-mae:2441.82	eval-mae:9904.81
# [4000]	train-mae:2397.18	eval-mae:9882.96
# [4100]	train-mae:2361.86	eval-mae:9851.88
# [4200]	train-mae:2325.18	eval-mae:9833.57
# [4300]	train-mae:2289.78	eval-mae:9819.79
# [4400]	train-mae:2257.97	eval-mae:9802.31
# [4500]	train-mae:2221.9	eval-mae:9784.94
# [4600]	train-mae:2188.36	eval-mae:9743.98
# [4700]	train-mae:2157.53	eval-mae:9718.53
# [4800]	train-mae:2127.79	eval-mae:9698.45
# [4900]	train-mae:2094.4	eval-mae:9679.45
# [4999]	train-mae:2066.21	eval-mae:9661.13

# %%
xgb_train_pred = (xgb_model.predict(d_train))
xgb_val_pred = (xgb_model.predict(d_val))

# %%
valid =val_y.values

import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
plt.plot(valid, label='true')
plt.plot(xgb_val_pred , label='pred')
plt.legend()
plt.show() #꽤잘나왔는데 ...?저 뒤에 신발종류 빼고 돌리면 되겠다.

# %%
from sklearn import metrics
print("MAE:", metrics.mean_absolute_error(valid, xgb_val_pred))
print('MSE:', metrics.mean_squared_error(valid, xgb_val_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(valid, xgb_val_pred)))
# Out:
# MAE: 9661.178008928242
# MSE: 342347020.45010597
# RMSE: 18502.62198852114

# %%
xgb_prediction_df = pd.DataFrame(val_df['date'], columns=['date'])
xgb_prediction_df['name'] = df_val['name']
xgb_prediction_df['size'] = df_val['size']
xgb_prediction_df['targetprice'] = val_df['targetprice']

xgb_prediction_df['pred'] = xgb_val_pred
xgb_prediction_df
# Out:
#              date                                name  size    targetprice  \
# 0      2022-06-16  (W) Nike Air Force 1 '07 Low White   220  145111.111111
# 1      2022-06-17  (W) Nike Air Force 1 '07 Low White   220  147750.000000
# 2      2022-06-17  (W) Nike Air Force 1 '07 Low White   220  147750.000000
# 3      2022-06-18  (W) Nike Air Force 1 '07 Low White   220  147666.666667
# 4      2022-06-18  (W) Nike Air Force 1 '07 Low White   220  147666.666667
# ...           ...                                 ...   ...            ...
# 12696  2022-06-25   Nike Dunk Low Retro PRM Halloween   310  233000.000000
# 12697  2022-06-25   Nike Dunk Low Retro PRM Halloween   310  233000.000000
# 12698  2022-06-25   Nike Dunk Low Retro PRM Halloween   310  233000.000000
# 12699  2022-06-25   Nike Dunk Low Retro PRM Halloween   310  233000.000000
# 12700  2022-06-25   Nike Dunk Low Retro PRM Halloween   310  233000.000000
#
#                 pred
# 0      146333.250000
# 1      146745.921875
# 2      146500.296875
# 3      146795.765625
# 4      146533.890625
# ...              ...
# 12696  209104.343750
# 12697  203189.703125
# 12698  205317.625000
# 12699  205571.437500
# 12700  202935.328125
#
# [12701 rows x 5 columns]

# %%
np.mean(xgb_prediction_df['targetprice']-xgb_prediction_df['pred']) # 평균 2700원 차이 !!!
# Out:
# -2753.3185869386894

# %%
max(xgb_prediction_df['targetprice']-xgb_prediction_df['pred']) #뒤에 신발 없애고 브랜드별로 나눠서 해봐야겠음
# Out:
# 59246.125

# %%
groups = xgb_prediction_df.groupby(['date','name','size'])
targetmean = groups.mean()['targetprice']
predmean = groups.mean()['pred']

groupdata = pd.DataFrame([targetmean, predmean]).transpose()
groupdata.columns=['target','prediction']
groupdata #최종!! 날짜별 신발들의 사이즈별 평균 예측
# Out:
#                                                            target  \
# date       name                               size
# 2022-06-16 (W) Nike Air Force 1 '07 Low White 220   145111.111111
#                                               225   135666.666667
#                                               230   135878.787879
#                                               235   136315.789474
#                                               240   138157.894737
# ...                                                           ...
# 2022-07-02 Nike Dunk Low Retro PRM Halloween  270   245769.230769
#                                               275   243125.000000
#                                               280   250285.714286
#                                               285   255000.000000
#                                               290   267000.000000
#
#                                                        prediction
# date       name                               size
# 2022-06-16 (W) Nike Air Force 1 '07 Low White 220   146333.250000
#                                               225   135045.062500
#                                               230   135970.265625
#                                               235   135984.843750
#                                               240   138175.562500
# ...                                                           ...
# 2022-07-02 Nike Dunk Low Retro PRM Halloween  270   234336.578125
#                                               275   235677.015625
#                                               280   253308.796875
#                                               285   270204.468750
#                                               290   277170.906250
#
# [1700 rows x 2 columns]

# %%
np.mean(groupdata['target']-groupdata['prediction']) # 평균 600원 차이 !!!
# Out:
# -2187.4309503251957

# %%
max(groupdata['target']-groupdata['prediction'])
# Out:
# 45674.5625

# %%
feature_important = xgb_model.get_score(importance_type='weight')
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(40, columns="score").plot(kind='barh', figsize = (20,10)) ## plot top 40 features

# %%
data.index.values
# Out:
# array(['duration', 'transaction_t', 'mean', 'max', 'todaycount', 'min',
#        'scrab', 'name_Nike Dunk Low Retro PRM Halloween', 'cumdate',
#        'cumtrans', 'name_New Balance 993 Made in USA Grey - D Standard',
#        'name_Jordan 1 Mid Light Smoke Gray Anthracite',
#        'name_Jordan 1 Low Golf Wolf Grey',
#        'name_Nike Dunk Low Retro Valerian Blue',
#        'name_Jordan 1 Retro High OG Black Mocha',
#        'name_Nike x Sacai x Fragment LDWaffle Light Smoke Grey',
#        'name_New Balance 992 Made in USA Grey - D Standard',
#        'brand_Jordan', 'color_WHITE', 'name_Adidas Yeezy Foam RNNR Onyx',
#        'day', "name_(W) Nike Air Force 1 '07 Low White", 'brand_Nike',
#        "name_Nike Air Force 1 '07 Low White", 'brand_New Balance',
#        'month', 'weekend'], dtype=object)

# %% [markdown]
# ###xgb2

# %%
# 중요도 top들로만 
xgb_train = train_df[data.index.values]
xgb_val = val_df[data.index.values]

# %%
train_y = train_df['targetprice']
val_y = val_df['targetprice']

# %%
params = {
    'learning_rate': 0.02,
    'objective': 'reg:squarederror',
    'eval_metric':'mae', 
    'seed':42
}

# %%
import xgboost as xgb

d_train = xgb.DMatrix(data=xgb_train, label = train_y)
d_val = xgb.DMatrix(data=xgb_val, label = val_y)
wlist = [(d_train, 'train'), (d_val,'eval')]

xgb_model = xgb.train(params, d_train, 1000, evals=wlist, verbose_eval=100, early_stopping_rounds=100)
# Out:
# [0]	train-mae:349671	eval-mae:343620
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# [100]	train-mae:46564.7	eval-mae:45161.7
# [200]	train-mae:7735.28	eval-mae:9321.47
# [300]	train-mae:3288.7	eval-mae:5032.21
# [400]	train-mae:2468.26	eval-mae:3790.26
# [500]	train-mae:2162.13	eval-mae:3228.01
# [600]	train-mae:1931.33	eval-mae:2879.59
# [700]	train-mae:1751.02	eval-mae:2656.31
# [800]	train-mae:1606.27	eval-mae:2482.14
# [900]	train-mae:1479.8	eval-mae:2337.85
# [999]	train-mae:1387.52	eval-mae:2230.45

# %%
xgb_train_pred = (xgb_model.predict(d_train))
xgb_val_pred = (xgb_model.predict(d_val))

# %%
valid =val_y.values

import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
plt.plot(valid, label='true')
plt.plot(xgb_val_pred , label='pred')
plt.legend()
plt.show()

# %%
from sklearn import metrics
print("MAE:", metrics.mean_absolute_error(valid, xgb_val_pred))
print('MSE:', metrics.mean_squared_error(valid, xgb_val_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(valid, xgb_val_pred)))
# Out:
# MAE: 2230.4551084842055
# MSE: 34788347.443325706
# RMSE: 5898.164752134829

# %%
xgb_prediction_df = pd.DataFrame(val_df['date'], columns=['date'])
xgb_prediction_df['targetprice'] = val_df['targetprice']
xgb_prediction_df['pred'] = xgb_val_pred
xgb_prediction_df
# Out:
#             date    targetprice           pred
# 0     2022-03-30  136755.555556  136057.671875
# 1     2022-03-30  136793.548387  136057.671875
# 2     2022-03-30  137238.709677  136057.671875
# 3     2022-03-30  137717.791411  136057.671875
# 4     2022-03-30  137429.577465  136057.671875
# ...          ...            ...            ...
# 6894  2022-06-29  754529.411765  753870.125000
# 6895  2022-06-29  782285.714286  779559.500000
# 6896  2022-06-30  711428.571429  712040.625000
# 6897  2022-06-30  754529.411765  753870.125000
# 6898  2022-07-01  711428.571429  712266.187500
#
# [6899 rows x 3 columns]

# %%
np.mean(xgb_prediction_df['targetprice']-xgb_prediction_df['pred']) #7천원 차이 ..
# Out:
# -216.03660834117915

# %% [markdown]
# ### xgb w/ optuna tuning

# %% [markdown]
# **0단계: 파라미터 고정**

# %%
dtrain = xgb.DMatrix(data=xgb_train, label = train_y)
dval_x = xgb.DMatrix(xgb_val)

# %%
param = {
	'eta': 0.05,
  'num_boost_rounds': 3000,
	'eval_metric': 'mae',
	'seed': 1,
  'max_depth': 5,
	'min_child_weight': 1,
  'gamma': 0,
  'sub_sample': 0.8,
  'colsample_bytree': 0.8,
}

model = xgb.train(param, dtrain)

# %%
preds = model.predict(dval_x)
score = metrics.mean_absolute_error(val_y, preds)
score
# Out:
# 112311.54758301866

# %% [markdown]
# **1단계: max_depth & min_child_weight 튜닝**

# %%
def objectiveXGB(trial, train_x = xgb_train, train_y = train_y, val_x = xgb_val, val_y = val_y):
		param = {
			'eta': 0.05,
  		'num_boost_rounds': 3000,
			'eval_metric': 'mae',
			'seed': 1,
			'max_depth': trial.suggest_int('max_depth', 3 ,18),
			'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
			'gamma': 0,
			'sub_sample': 0.8,
			'colsample_bytree': 0.8
		}

		dtrain = xgb.DMatrix(data=xgb_train, label = train_y)
		dval_x = xgb.DMatrix(xgb_val)

		model = xgb.train(param, dtrain)

		preds = model.predict(dval_x)
		
		score = metrics.mean_absolute_error(val_y, preds)
 
		return score

# %%
# !pip install optuna

# %%
import optuna
from optuna import Trial, visualization

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objectiveXGB, n_trials = 50)
print('Best trial: score {},\nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# [I 2022-07-08 02:38:55,958] A new study created in memory with name: no-name-1df3ae0e-6d1a-446a-af6a-71ab8f0035da
# [I 2022-07-08 02:38:56,072] Trial 0 finished with value: 111469.28146865281 and parameters: {'max_depth': 3, 'min_child_weight': 63}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:56,239] Trial 1 finished with value: 113108.0981612339 and parameters: {'max_depth': 10, 'min_child_weight': 176}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:56,363] Trial 2 finished with value: 111912.7408981425 and parameters: {'max_depth': 4, 'min_child_weight': 279}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:56,534] Trial 3 finished with value: 113159.70919868947 and parameters: {'max_depth': 17, 'min_child_weight': 253}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:56,706] Trial 4 finished with value: 113268.02369953632 and parameters: {'max_depth': 11, 'min_child_weight': 69}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:56,897] Trial 5 finished with value: 113310.49392283984 and parameters: {'max_depth': 17, 'min_child_weight': 6}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:57,067] Trial 6 finished with value: 113158.9652619669 and parameters: {'max_depth': 13, 'min_child_weight': 205}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:57,226] Trial 7 finished with value: 112739.20526640938 and parameters: {'max_depth': 7, 'min_child_weight': 218}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:57,399] Trial 8 finished with value: 113270.25265680531 and parameters: {'max_depth': 10, 'min_child_weight': 58}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:57,561] Trial 9 finished with value: 113114.79112061307 and parameters: {'max_depth': 8, 'min_child_weight': 179}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:57,675] Trial 10 finished with value: 111469.428267992 and parameters: {'max_depth': 3, 'min_child_weight': 104}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:57,787] Trial 11 finished with value: 111469.428267992 and parameters: {'max_depth': 3, 'min_child_weight': 108}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:57,936] Trial 12 finished with value: 112296.811611506 and parameters: {'max_depth': 5, 'min_child_weight': 118}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:58,092] Trial 13 finished with value: 112512.39869259496 and parameters: {'max_depth': 6, 'min_child_weight': 6}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:58,205] Trial 14 finished with value: 111469.31834635996 and parameters: {'max_depth': 3, 'min_child_weight': 79}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:58,382] Trial 15 finished with value: 113270.25265680531 and parameters: {'max_depth': 8, 'min_child_weight': 54}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:58,557] Trial 16 finished with value: 113108.11250728843 and parameters: {'max_depth': 14, 'min_child_weight': 135}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:58,698] Trial 17 finished with value: 112311.66865420924 and parameters: {'max_depth': 5, 'min_child_weight': 38}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:58,809] Trial 18 finished with value: 111469.428267992 and parameters: {'max_depth': 3, 'min_child_weight': 86}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:58,969] Trial 19 finished with value: 112469.2667703243 and parameters: {'max_depth': 6, 'min_child_weight': 148}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:59,153] Trial 20 finished with value: 113311.04440387606 and parameters: {'max_depth': 15, 'min_child_weight': 32}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:59,262] Trial 21 finished with value: 111469.31834635996 and parameters: {'max_depth': 3, 'min_child_weight': 83}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:59,387] Trial 22 finished with value: 111840.95640999834 and parameters: {'max_depth': 4, 'min_child_weight': 83}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:59,523] Trial 23 finished with value: 112295.90621355786 and parameters: {'max_depth': 5, 'min_child_weight': 91}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:59,693] Trial 24 finished with value: 113114.7922104065 and parameters: {'max_depth': 8, 'min_child_weight': 129}. Best is trial 0 with value: 111469.28146865281.
# [I 2022-07-08 02:38:59,805] Trial 25 finished with value: 111469.20284908096 and parameters: {'max_depth': 3, 'min_child_weight': 35}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:38:59,969] Trial 26 finished with value: 112490.5568427921 and parameters: {'max_depth': 6, 'min_child_weight': 34}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:00,095] Trial 27 finished with value: 111846.25594527432 and parameters: {'max_depth': 4, 'min_child_weight': 21}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:00,264] Trial 28 finished with value: 112717.1053073634 and parameters: {'max_depth': 7, 'min_child_weight': 53}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:00,389] Trial 29 finished with value: 111909.49563562027 and parameters: {'max_depth': 4, 'min_child_weight': 174}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:00,571] Trial 30 finished with value: 113267.96869273379 and parameters: {'max_depth': 12, 'min_child_weight': 63}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:00,681] Trial 31 finished with value: 111469.31834635996 and parameters: {'max_depth': 3, 'min_child_weight': 77}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:00,792] Trial 32 finished with value: 111469.428267992 and parameters: {'max_depth': 3, 'min_child_weight': 95}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:00,936] Trial 33 finished with value: 112311.66865420924 and parameters: {'max_depth': 5, 'min_child_weight': 46}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:01,070] Trial 34 finished with value: 111834.01934209796 and parameters: {'max_depth': 4, 'min_child_weight': 26}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:01,243] Trial 35 finished with value: 113126.87137834574 and parameters: {'max_depth': 10, 'min_child_weight': 296}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:01,366] Trial 36 finished with value: 111846.25594527432 and parameters: {'max_depth': 4, 'min_child_weight': 1}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:01,544] Trial 37 finished with value: 113268.00527543314 and parameters: {'max_depth': 18, 'min_child_weight': 66}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:01,706] Trial 38 finished with value: 112715.01111658708 and parameters: {'max_depth': 7, 'min_child_weight': 72}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:01,818] Trial 39 finished with value: 111469.428267992 and parameters: {'max_depth': 3, 'min_child_weight': 117}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:01,959] Trial 40 finished with value: 112311.54758301866 and parameters: {'max_depth': 5, 'min_child_weight': 17}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:02,080] Trial 41 finished with value: 111469.31834635996 and parameters: {'max_depth': 3, 'min_child_weight': 77}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:02,207] Trial 42 finished with value: 111910.94252901488 and parameters: {'max_depth': 4, 'min_child_weight': 255}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:02,317] Trial 43 finished with value: 111469.30708573967 and parameters: {'max_depth': 3, 'min_child_weight': 75}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:02,470] Trial 44 finished with value: 112464.6134860201 and parameters: {'max_depth': 6, 'min_child_weight': 102}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:02,585] Trial 45 finished with value: 111469.23693462627 and parameters: {'max_depth': 3, 'min_child_weight': 48}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:02,760] Trial 46 finished with value: 113270.25265680531 and parameters: {'max_depth': 9, 'min_child_weight': 55}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:02,904] Trial 47 finished with value: 112311.54758301866 and parameters: {'max_depth': 5, 'min_child_weight': 17}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:03,040] Trial 48 finished with value: 111834.05670917092 and parameters: {'max_depth': 4, 'min_child_weight': 38}. Best is trial 25 with value: 111469.20284908096.
# [I 2022-07-08 02:39:03,152] Trial 49 finished with value: 111469.23693462627 and parameters: {'max_depth': 3, 'min_child_weight': 47}. Best is trial 25 with value: 111469.20284908096.
# Best trial: score 111469.20284908096,
# params {'max_depth': 3, 'min_child_weight': 35}

# %%
# 하이퍼파라미터별 중요도를 확인할 수 있는 그래프
optuna.visualization.plot_param_importances(study)

# %% [markdown]
# *   두 파라미터 중요도 차이가 너무 많이 나서 min_child_weight 다시 튜닝

# %%
def objectiveXGB(trial, train_x = xgb_train, train_y = train_y, val_x = xgb_val, val_y = val_y):
		param = {
			'eta': 0.05,
  		'num_boost_rounds': 3000,
			'eval_metric': 'mae',
			'seed': 1,
			'max_depth': 3,
			'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
			'gamma': 0,
			'sub_sample': 0.8,
			'colsample_bytree': 0.8
		}

		dtrain = xgb.DMatrix(data=xgb_train, label = train_y)
		dval_x = xgb.DMatrix(xgb_val)

		model = xgb.train(param, dtrain)

		preds = model.predict(dval_x)
		
		score = metrics.mean_absolute_error(val_y, preds)
 
		return score

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objectiveXGB, n_trials = 50)
print('Best trial: score {},\nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# [I 2022-07-08 02:41:16,765] A new study created in memory with name: no-name-90af39a2-ff75-4022-9e24-07dee47d8a24
# [I 2022-07-08 02:41:16,994] Trial 0 finished with value: 111469.428267992 and parameters: {'min_child_weight': 164}. Best is trial 0 with value: 111469.428267992.
# [I 2022-07-08 02:41:17,165] Trial 1 finished with value: 111469.428267992 and parameters: {'min_child_weight': 111}. Best is trial 0 with value: 111469.428267992.
# [I 2022-07-08 02:41:17,438] Trial 2 finished with value: 111469.428267992 and parameters: {'min_child_weight': 138}. Best is trial 0 with value: 111469.428267992.
# [I 2022-07-08 02:41:17,631] Trial 3 finished with value: 111469.428267992 and parameters: {'min_child_weight': 160}. Best is trial 0 with value: 111469.428267992.
# [I 2022-07-08 02:41:17,807] Trial 4 finished with value: 111469.428267992 and parameters: {'min_child_weight': 189}. Best is trial 0 with value: 111469.428267992.
# [I 2022-07-08 02:41:17,978] Trial 5 finished with value: 111469.428267992 and parameters: {'min_child_weight': 109}. Best is trial 0 with value: 111469.428267992.
# [I 2022-07-08 02:41:18,154] Trial 6 finished with value: 111469.428267992 and parameters: {'min_child_weight': 217}. Best is trial 0 with value: 111469.428267992.
# [I 2022-07-08 02:41:18,325] Trial 7 finished with value: 111354.95214626832 and parameters: {'min_child_weight': 19}. Best is trial 7 with value: 111354.95214626832.
# [I 2022-07-08 02:41:18,515] Trial 8 finished with value: 111470.09779507719 and parameters: {'min_child_weight': 262}. Best is trial 7 with value: 111354.95214626832.
# [I 2022-07-08 02:41:18,703] Trial 9 finished with value: 111354.95214626832 and parameters: {'min_child_weight': 23}. Best is trial 7 with value: 111354.95214626832.
# [I 2022-07-08 02:41:18,868] Trial 10 finished with value: 111354.95214626832 and parameters: {'min_child_weight': 8}. Best is trial 7 with value: 111354.95214626832.
# [I 2022-07-08 02:41:19,043] Trial 11 finished with value: 111354.95214626832 and parameters: {'min_child_weight': 3}. Best is trial 7 with value: 111354.95214626832.
# [I 2022-07-08 02:41:19,210] Trial 12 finished with value: 111469.28146865281 and parameters: {'min_child_weight': 62}. Best is trial 7 with value: 111354.95214626832.
# [I 2022-07-08 02:41:19,403] Trial 13 finished with value: 111469.28146865281 and parameters: {'min_child_weight': 60}. Best is trial 7 with value: 111354.95214626832.
# [I 2022-07-08 02:41:19,577] Trial 14 finished with value: 111469.28146865281 and parameters: {'min_child_weight': 54}. Best is trial 7 with value: 111354.95214626832.
# [I 2022-07-08 02:41:19,757] Trial 15 finished with value: 111469.20284908096 and parameters: {'min_child_weight': 41}. Best is trial 7 with value: 111354.95214626832.
# [I 2022-07-08 02:41:19,941] Trial 16 finished with value: 111469.428267992 and parameters: {'min_child_weight': 98}. Best is trial 7 with value: 111354.95214626832.
# [I 2022-07-08 02:41:20,105] Trial 17 finished with value: 111354.95214626832 and parameters: {'min_child_weight': 3}. Best is trial 7 with value: 111354.95214626832.
# [I 2022-07-08 02:41:20,289] Trial 18 finished with value: 111350.57371029543 and parameters: {'min_child_weight': 300}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:20,471] Trial 19 finished with value: 111350.57371029543 and parameters: {'min_child_weight': 300}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:20,648] Trial 20 finished with value: 111350.57371029543 and parameters: {'min_child_weight': 297}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:20,839] Trial 21 finished with value: 111350.57371029543 and parameters: {'min_child_weight': 300}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:21,021] Trial 22 finished with value: 111350.57371029543 and parameters: {'min_child_weight': 298}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:21,202] Trial 23 finished with value: 111470.12839953076 and parameters: {'min_child_weight': 255}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:21,414] Trial 24 finished with value: 111470.01229314749 and parameters: {'min_child_weight': 269}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:21,584] Trial 25 finished with value: 111469.428267992 and parameters: {'min_child_weight': 229}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:21,757] Trial 26 finished with value: 111470.01229314749 and parameters: {'min_child_weight': 276}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:21,882] Trial 27 finished with value: 111470.12839953076 and parameters: {'min_child_weight': 231}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:21,994] Trial 28 finished with value: 111350.57371029543 and parameters: {'min_child_weight': 284}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:22,107] Trial 29 finished with value: 111469.428267992 and parameters: {'min_child_weight': 193}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:22,216] Trial 30 finished with value: 111470.12839953076 and parameters: {'min_child_weight': 247}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:22,325] Trial 31 finished with value: 111358.9769807169 and parameters: {'min_child_weight': 282}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:22,436] Trial 32 finished with value: 111350.57371029543 and parameters: {'min_child_weight': 285}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:22,547] Trial 33 finished with value: 111470.12839953076 and parameters: {'min_child_weight': 241}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:22,660] Trial 34 finished with value: 111358.9769807169 and parameters: {'min_child_weight': 281}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:22,772] Trial 35 finished with value: 111469.428267992 and parameters: {'min_child_weight': 210}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:22,891] Trial 36 finished with value: 111358.9769807169 and parameters: {'min_child_weight': 283}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:22,997] Trial 37 finished with value: 111469.428267992 and parameters: {'min_child_weight': 141}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:23,105] Trial 38 finished with value: 111470.12839953076 and parameters: {'min_child_weight': 257}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:23,212] Trial 39 finished with value: 111469.428267992 and parameters: {'min_child_weight': 177}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:23,327] Trial 40 finished with value: 111350.57371029543 and parameters: {'min_child_weight': 289}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:23,440] Trial 41 finished with value: 111350.57371029543 and parameters: {'min_child_weight': 300}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:23,552] Trial 42 finished with value: 111470.01229314749 and parameters: {'min_child_weight': 268}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:23,663] Trial 43 finished with value: 111350.57371029543 and parameters: {'min_child_weight': 297}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:23,777] Trial 44 finished with value: 111470.01229314749 and parameters: {'min_child_weight': 280}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:23,900] Trial 45 finished with value: 111350.57371029543 and parameters: {'min_child_weight': 299}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:24,010] Trial 46 finished with value: 111470.01229314749 and parameters: {'min_child_weight': 264}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:24,121] Trial 47 finished with value: 111470.12839953076 and parameters: {'min_child_weight': 244}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:24,232] Trial 48 finished with value: 111469.428267992 and parameters: {'min_child_weight': 211}. Best is trial 18 with value: 111350.57371029543.
# [I 2022-07-08 02:41:24,342] Trial 49 finished with value: 111470.01229314749 and parameters: {'min_child_weight': 273}. Best is trial 18 with value: 111350.57371029543.
# Best trial: score 111350.57371029543,
# params {'min_child_weight': 300}

# %% [markdown]
# **2단계: gamma 튜닝**

# %%
def objectiveXGB(trial, train_x = xgb_train, train_y = train_y, val_x = xgb_val, val_y = val_y):
		param = {
			'eta': 0.05,
  		'num_boost_rounds': 3000,
			'eval_metric': 'mae',
			'seed': 1,
			'max_depth': 3,
			'min_child_weight': 300,
			'gamma': trial.suggest_categorical('gamma', [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]),
			'sub_sample': 0.8,
			'colsample_bytree': 0.8
		}

		dtrain = xgb.DMatrix(data=xgb_train, label = train_y)
		dval_x = xgb.DMatrix(xgb_val)

		model = xgb.train(param, dtrain)

		preds = model.predict(dval_x)
		
		score = metrics.mean_absolute_error(val_y, preds)
 
		return score

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objectiveXGB, n_trials = 50)
print('Best trial: score {},\nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# [I 2022-07-08 02:42:23,225] A new study created in memory with name: no-name-cbb123e5-40a5-4f70-8a48-0119791194f5
# [I 2022-07-08 02:42:23,487] Trial 0 finished with value: 111350.57371029543 and parameters: {'gamma': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:23,705] Trial 1 finished with value: 111350.57371029543 and parameters: {'gamma': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:23,952] Trial 2 finished with value: 111350.57371029543 and parameters: {'gamma': 0}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:24,137] Trial 3 finished with value: 111350.57371029543 and parameters: {'gamma': 0.15}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:24,439] Trial 4 finished with value: 111350.57371029543 and parameters: {'gamma': 0.3}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:24,690] Trial 5 finished with value: 111350.57371029543 and parameters: {'gamma': 0.1}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:24,932] Trial 6 finished with value: 111350.57371029543 and parameters: {'gamma': 0.45}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:25,152] Trial 7 finished with value: 111350.57371029543 and parameters: {'gamma': 0.4}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:25,383] Trial 8 finished with value: 111350.57371029543 and parameters: {'gamma': 0.25}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:25,681] Trial 9 finished with value: 111350.57371029543 and parameters: {'gamma': 0.1}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:25,853] Trial 10 finished with value: 111350.57371029543 and parameters: {'gamma': 0.2}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:26,020] Trial 11 finished with value: 111350.57371029543 and parameters: {'gamma': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:26,281] Trial 12 finished with value: 111350.57371029543 and parameters: {'gamma': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:26,465] Trial 13 finished with value: 111350.57371029543 and parameters: {'gamma': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:26,642] Trial 14 finished with value: 111350.57371029543 and parameters: {'gamma': 0.35}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:26,816] Trial 15 finished with value: 111350.57371029543 and parameters: {'gamma': 0.05}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:27,020] Trial 16 finished with value: 111350.57371029543 and parameters: {'gamma': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:27,241] Trial 17 finished with value: 111350.57371029543 and parameters: {'gamma': 0.35}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:27,492] Trial 18 finished with value: 111350.57371029543 and parameters: {'gamma': 0.05}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:27,685] Trial 19 finished with value: 111350.57371029543 and parameters: {'gamma': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:27,859] Trial 20 finished with value: 111350.57371029543 and parameters: {'gamma': 0.35}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:28,032] Trial 21 finished with value: 111350.57371029543 and parameters: {'gamma': 0.05}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:28,221] Trial 22 finished with value: 111350.57371029543 and parameters: {'gamma': 0.05}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:28,434] Trial 23 finished with value: 111350.57371029543 and parameters: {'gamma': 0.35}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:28,633] Trial 24 finished with value: 111350.57371029543 and parameters: {'gamma': 0.25}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:28,811] Trial 25 finished with value: 111350.57371029543 and parameters: {'gamma': 0.05}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:28,989] Trial 26 finished with value: 111350.57371029543 and parameters: {'gamma': 0.2}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:29,164] Trial 27 finished with value: 111350.57371029543 and parameters: {'gamma': 0.25}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:29,340] Trial 28 finished with value: 111350.57371029543 and parameters: {'gamma': 0.25}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:29,492] Trial 29 finished with value: 111350.57371029543 and parameters: {'gamma': 0.2}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:29,604] Trial 30 finished with value: 111350.57371029543 and parameters: {'gamma': 0.2}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:29,712] Trial 31 finished with value: 111350.57371029543 and parameters: {'gamma': 0.25}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:29,823] Trial 32 finished with value: 111350.57371029543 and parameters: {'gamma': 0.25}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:29,934] Trial 33 finished with value: 111350.57371029543 and parameters: {'gamma': 0.2}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:30,044] Trial 34 finished with value: 111350.57371029543 and parameters: {'gamma': 0}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:30,153] Trial 35 finished with value: 111350.57371029543 and parameters: {'gamma': 0.15}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:30,272] Trial 36 finished with value: 111350.57371029543 and parameters: {'gamma': 0.05}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:30,381] Trial 37 finished with value: 111350.57371029543 and parameters: {'gamma': 0.3}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:30,488] Trial 38 finished with value: 111350.57371029543 and parameters: {'gamma': 0.45}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:30,603] Trial 39 finished with value: 111350.57371029543 and parameters: {'gamma': 0.4}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:30,716] Trial 40 finished with value: 111350.57371029543 and parameters: {'gamma': 0.35}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:30,826] Trial 41 finished with value: 111350.57371029543 and parameters: {'gamma': 0.05}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:30,937] Trial 42 finished with value: 111350.57371029543 and parameters: {'gamma': 0}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:31,053] Trial 43 finished with value: 111350.57371029543 and parameters: {'gamma': 0.1}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:31,164] Trial 44 finished with value: 111350.57371029543 and parameters: {'gamma': 0.25}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:31,282] Trial 45 finished with value: 111350.57371029543 and parameters: {'gamma': 0.25}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:31,391] Trial 46 finished with value: 111350.57371029543 and parameters: {'gamma': 0.15}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:31,507] Trial 47 finished with value: 111350.57371029543 and parameters: {'gamma': 0.45}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:31,619] Trial 48 finished with value: 111350.57371029543 and parameters: {'gamma': 0.2}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:42:31,727] Trial 49 finished with value: 111350.57371029543 and parameters: {'gamma': 0.2}. Best is trial 0 with value: 111350.57371029543.
# Best trial: score 111350.57371029543,
# params {'gamma': 0.5}

# %% [markdown]
# **3단계: sub_sample & colsample_bytree**

# %%
def objectiveXGB(trial, train_x = xgb_train, train_y = train_y, val_x = xgb_val, val_y = val_y):
		param = {
			'eta': 0.05,
			'num_boost_rounds': 3000,
			'eval_metric': 'mae',
			'seed': 1,
			'max_depth': 3,
			'min_child_weight': 300,
			'gamma': 0.5,
			'sub_sample': trial.suggest_categorical('sub_sample', [0.6, 0.65, 0.7, 0.75, 0.8, 0.85]),
			'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.6, 0.65, 0.7, 0.75, 0.8, 0.85])
		}

		dtrain = xgb.DMatrix(data=xgb_train, label = train_y)
		dval_x = xgb.DMatrix(xgb_val)

		model = xgb.train(param, dtrain)

		preds = model.predict(dval_x)
		
		score = metrics.mean_absolute_error(val_y, preds)
 
		return score

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objectiveXGB, n_trials = 50)
print('Best trial: score {},\nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# [I 2022-07-08 02:44:24,318] A new study created in memory with name: no-name-7fccf11d-b4ee-4399-a566-ec56656d73e6
# [I 2022-07-08 02:44:24,424] Trial 0 finished with value: 111435.81674811195 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.7}. Best is trial 0 with value: 111435.81674811195.
# [I 2022-07-08 02:44:24,537] Trial 1 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:24,646] Trial 2 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:24,747] Trial 3 finished with value: 111435.81674811195 and parameters: {'sub_sample': 0.6, 'colsample_bytree': 0.7}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:24,855] Trial 4 finished with value: 111483.58041911929 and parameters: {'sub_sample': 0.65, 'colsample_bytree': 0.75}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:24,959] Trial 5 finished with value: 111706.70806898324 and parameters: {'sub_sample': 0.75, 'colsample_bytree': 0.6}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:25,061] Trial 6 finished with value: 111483.58041911929 and parameters: {'sub_sample': 0.65, 'colsample_bytree': 0.75}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:25,169] Trial 7 finished with value: 111706.70806898324 and parameters: {'sub_sample': 0.85, 'colsample_bytree': 0.6}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:25,271] Trial 8 finished with value: 111483.58041911929 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.75}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:25,374] Trial 9 finished with value: 111435.81674811195 and parameters: {'sub_sample': 0.85, 'colsample_bytree': 0.7}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:25,494] Trial 10 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:25,605] Trial 11 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:25,717] Trial 12 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:25,822] Trial 13 finished with value: 111706.70806898324 and parameters: {'sub_sample': 0.75, 'colsample_bytree': 0.65}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:25,933] Trial 14 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:26,043] Trial 15 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.6, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:26,153] Trial 16 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:26,266] Trial 17 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:26,379] Trial 18 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:26,492] Trial 19 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:26,607] Trial 20 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:26,715] Trial 21 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:26,827] Trial 22 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:26,929] Trial 23 finished with value: 111706.70806898324 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.65}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:27,042] Trial 24 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:27,156] Trial 25 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:27,255] Trial 26 finished with value: 111706.70806898324 and parameters: {'sub_sample': 0.85, 'colsample_bytree': 0.65}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:27,357] Trial 27 finished with value: 111706.70806898324 and parameters: {'sub_sample': 0.6, 'colsample_bytree': 0.6}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:27,468] Trial 28 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:27,593] Trial 29 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:27,704] Trial 30 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:27,816] Trial 31 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.6, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:27,925] Trial 32 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:28,034] Trial 33 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:28,148] Trial 34 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.6, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:28,258] Trial 35 finished with value: 111435.81674811195 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.7}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:28,379] Trial 36 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:28,490] Trial 37 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.6, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:28,607] Trial 38 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.65, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:28,721] Trial 39 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:28,835] Trial 40 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:28,961] Trial 41 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.85}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:29,097] Trial 42 finished with value: 111483.58041911929 and parameters: {'sub_sample': 0.7, 'colsample_bytree': 0.75}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:29,265] Trial 43 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.6, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:29,421] Trial 44 finished with value: 111706.70806898324 and parameters: {'sub_sample': 0.65, 'colsample_bytree': 0.6}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:29,607] Trial 45 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:29,776] Trial 46 finished with value: 111435.81674811195 and parameters: {'sub_sample': 0.75, 'colsample_bytree': 0.7}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:29,955] Trial 47 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:30,126] Trial 48 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# [I 2022-07-08 02:44:30,299] Trial 49 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8, 'colsample_bytree': 0.8}. Best is trial 1 with value: 111350.57371029543.
# Best trial: score 111350.57371029543,
# params {'sub_sample': 0.75, 'colsample_bytree': 0.85}

# %%
# 하이퍼파라미터별 중요도를 확인할 수 있는 그래프
optuna.visualization.plot_param_importances(study)

# %% [markdown]
# **4단계: subsample 추가 튜닝**

# %%
def objectiveXGB(trial, train_x = xgb_train, train_y = train_y, val_x = xgb_val, val_y = val_y):
		param = {
			'eta': 0.05,
			'num_boost_rounds': 3000,
			'eval_metric': 'mae',
			'seed': 1,
			'max_depth': 3,
			'min_child_weight': 300,
			'gamma': 0.5,
			'sub_sample': trial.suggest_categorical('sub_sample', [0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8]),
			'colsample_bytree': 0.85
		}

		dtrain = xgb.DMatrix(data=xgb_train, label = train_y)
		dval_x = xgb.DMatrix(xgb_val)

		model = xgb.train(param, dtrain)

		preds = model.predict(dval_x)
		
		score = metrics.mean_absolute_error(val_y, preds)
 
		return score

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objectiveXGB, n_trials = 50)
print('Best trial: score {},\nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# [I 2022-07-08 02:45:58,758] A new study created in memory with name: no-name-51d47f2b-10fc-4eee-8e19-905989d0f5c9
# [I 2022-07-08 02:45:58,938] Trial 0 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:45:59,115] Trial 1 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.6}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:45:59,296] Trial 2 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:45:59,474] Trial 3 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:45:59,661] Trial 4 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.6}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:45:59,842] Trial 5 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.65}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:00,018] Trial 6 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.55}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:00,203] Trial 7 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.6}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:00,377] Trial 8 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.4}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:00,576] Trial 9 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.65}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:00,756] Trial 10 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:00,929] Trial 11 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:01,105] Trial 12 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:01,283] Trial 13 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.45}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:01,459] Trial 14 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:01,637] Trial 15 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.6}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:01,819] Trial 16 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:02,001] Trial 17 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:02,167] Trial 18 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:02,276] Trial 19 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:02,387] Trial 20 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:02,500] Trial 21 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:02,617] Trial 22 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:02,726] Trial 23 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:02,838] Trial 24 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:02,949] Trial 25 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:03,062] Trial 26 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.4}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:03,173] Trial 27 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.55}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:03,289] Trial 28 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:03,405] Trial 29 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.4}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:03,515] Trial 30 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.55}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:03,631] Trial 31 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:03,748] Trial 32 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:03,859] Trial 33 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.55}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:03,970] Trial 34 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.4}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:04,084] Trial 35 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:04,194] Trial 36 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:04,307] Trial 37 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:04,417] Trial 38 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.5}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:04,527] Trial 39 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.45}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:04,635] Trial 40 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:04,755] Trial 41 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.75}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:04,869] Trial 42 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.4}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:04,979] Trial 43 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.65}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:05,090] Trial 44 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.55}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:05,206] Trial 45 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.8}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:05,316] Trial 46 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.7}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:05,433] Trial 47 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.55}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:05,543] Trial 48 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.4}. Best is trial 0 with value: 111350.57371029543.
# [I 2022-07-08 02:46:05,652] Trial 49 finished with value: 111350.57371029543 and parameters: {'sub_sample': 0.4}. Best is trial 0 with value: 111350.57371029543.
# Best trial: score 111350.57371029543,
# params {'sub_sample': 0.8}

# %% [markdown]
# **5단계: alpha & lambda 튜닝**

# %%
def objectiveXGB(trial, train_x = xgb_train, train_y = train_y, val_x = xgb_val, val_y = val_y):
		param = {
			'eta': 0.05,
			'num_boost_rounds': 3000,
			'eval_metric': 'mae',
			'seed': 1,
			'max_depth': 3,
			'min_child_weight': 300,
			'gamma': 0.5,
			'sub_sample': 0.8,
			'colsample_bytree': 0.85,
      'alpha': trial.suggest_categorical('alpha', [1e-5, 1e-2, 0.1, 1, 10, 20, 30, 50, 60, 70, 80, 90, 100]),
      'lamnbda': trial.suggest_categorical('lambda', [1e-5, 1e-2, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.5, 0.6])                                                
		}


		dtrain = xgb.DMatrix(data=train_x, label=train_y)
		dval_x = xgb.DMatrix(val_x)

		model = xgb.train(param, dtrain)

		preds = model.predict(dval_x)
		
		score = metrics.mean_absolute_error(val_y, preds)
 
		return score

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objectiveXGB, n_trials = 50)
print('Best trial: score {},\nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# [I 2022-07-08 02:47:59,083] A new study created in memory with name: no-name-9bfd04a9-7559-4eef-8f09-d0f92ade1aeb
# [I 2022-07-08 02:47:59,219] Trial 0 finished with value: 111350.57546993003 and parameters: {'alpha': 70, 'lambda': 0.5}. Best is trial 0 with value: 111350.57546993003.
# [I 2022-07-08 02:47:59,340] Trial 1 finished with value: 111350.57442178477 and parameters: {'alpha': 30, 'lambda': 0.25}. Best is trial 1 with value: 111350.57442178477.
# [I 2022-07-08 02:47:59,456] Trial 2 finished with value: 111350.57371029543 and parameters: {'alpha': 0.1, 'lambda': 0.3}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:47:59,565] Trial 3 finished with value: 111350.57417189583 and parameters: {'alpha': 20, 'lambda': 0.2}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:47:59,678] Trial 4 finished with value: 111350.57371029543 and parameters: {'alpha': 1, 'lambda': 0.15}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:47:59,790] Trial 5 finished with value: 111350.57371029543 and parameters: {'alpha': 1, 'lambda': 0.4}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:47:59,904] Trial 6 finished with value: 111350.57371029543 and parameters: {'alpha': 0.01, 'lambda': 0.5}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:00,017] Trial 7 finished with value: 111350.57371029543 and parameters: {'alpha': 0.01, 'lambda': 0.15}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:00,124] Trial 8 finished with value: 111350.5756816415 and parameters: {'alpha': 80, 'lambda': 1e-05}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:00,237] Trial 9 finished with value: 111350.57406604009 and parameters: {'alpha': 10, 'lambda': 0.3}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:00,359] Trial 10 finished with value: 111350.57371029543 and parameters: {'alpha': 0.1, 'lambda': 0.3}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:00,468] Trial 11 finished with value: 111350.57616233063 and parameters: {'alpha': 100, 'lambda': 0.01}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:00,584] Trial 12 finished with value: 111350.57371029543 and parameters: {'alpha': 0.1, 'lambda': 0.1}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:00,693] Trial 13 finished with value: 111350.5749892409 and parameters: {'alpha': 50, 'lambda': 0.15}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:00,806] Trial 14 finished with value: 111350.57593153043 and parameters: {'alpha': 90, 'lambda': 0.35}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:00,918] Trial 15 finished with value: 111350.57371029543 and parameters: {'alpha': 1, 'lambda': 0.6}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:01,031] Trial 16 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 0.3}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:01,141] Trial 17 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 0.3}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:01,255] Trial 18 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 0.3}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:01,373] Trial 19 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 0.3}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:01,484] Trial 20 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 0.6}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:01,598] Trial 21 finished with value: 111350.57523912983 and parameters: {'alpha': 60, 'lambda': 0.3}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:01,707] Trial 22 finished with value: 111350.57371029543 and parameters: {'alpha': 0.1, 'lambda': 0.1}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:01,818] Trial 23 finished with value: 111350.57371029543 and parameters: {'alpha': 1, 'lambda': 0.1}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:01,932] Trial 24 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 0.01}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:02,048] Trial 25 finished with value: 111350.57371029543 and parameters: {'alpha': 0.1, 'lambda': 0.1}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:02,163] Trial 26 finished with value: 111350.57371029543 and parameters: {'alpha': 0.1, 'lambda': 0.1}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:02,279] Trial 27 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 1e-05}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:02,401] Trial 28 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 1e-05}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:02,512] Trial 29 finished with value: 111350.57546993003 and parameters: {'alpha': 70, 'lambda': 0.6}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:02,622] Trial 30 finished with value: 111350.57371029543 and parameters: {'alpha': 0.1, 'lambda': 0.1}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:02,738] Trial 31 finished with value: 111350.57406604009 and parameters: {'alpha': 10, 'lambda': 1e-05}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:02,851] Trial 32 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 0.25}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:02,962] Trial 33 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 1e-05}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:03,083] Trial 34 finished with value: 111350.57442178477 and parameters: {'alpha': 30, 'lambda': 1e-05}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:03,197] Trial 35 finished with value: 111350.57417189583 and parameters: {'alpha': 20, 'lambda': 0.1}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:03,309] Trial 36 finished with value: 111350.57371029543 and parameters: {'alpha': 0.1, 'lambda': 0.2}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:03,435] Trial 37 finished with value: 111350.57616233063 and parameters: {'alpha': 100, 'lambda': 0.25}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:03,550] Trial 38 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 0.25}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:03,660] Trial 39 finished with value: 111350.5756816415 and parameters: {'alpha': 80, 'lambda': 0.2}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:03,773] Trial 40 finished with value: 111350.57523912983 and parameters: {'alpha': 60, 'lambda': 0.4}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:03,882] Trial 41 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 0.6}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:03,994] Trial 42 finished with value: 111350.57371029543 and parameters: {'alpha': 1e-05, 'lambda': 0.25}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:04,104] Trial 43 finished with value: 111350.57593153043 and parameters: {'alpha': 90, 'lambda': 0.25}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:04,214] Trial 44 finished with value: 111350.57371029543 and parameters: {'alpha': 1, 'lambda': 0.01}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:04,324] Trial 45 finished with value: 111350.5749892409 and parameters: {'alpha': 50, 'lambda': 0.1}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:04,445] Trial 46 finished with value: 111350.57371029543 and parameters: {'alpha': 0.1, 'lambda': 0.5}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:04,559] Trial 47 finished with value: 111350.57371029543 and parameters: {'alpha': 0.01, 'lambda': 0.01}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:04,669] Trial 48 finished with value: 111350.57371029543 and parameters: {'alpha': 0.1, 'lambda': 0.5}. Best is trial 2 with value: 111350.57371029543.
# [I 2022-07-08 02:48:04,780] Trial 49 finished with value: 111350.57371029543 and parameters: {'alpha': 0.01, 'lambda': 0.01}. Best is trial 2 with value: 111350.57371029543.
# Best trial: score 111350.57371029543,
# params {'alpha': 0.1, 'lambda': 0.3}

# %%
d_train = xgb.DMatrix(data=xgb_train, label = train_y)
d_val = xgb.DMatrix(data=xgb_val, label = val_y)
wlist = [(d_train, 'train'), (d_val,'eval')]

params = {
		'eta': 0.05,
		'num_boost_rounds': 3000,
		'eval_metric': 'mae',
		'seed': 1,
		'max_depth': 3,
		'min_child_weight': 300,
		'gamma': 0.5,
		'sub_sample': 0.8,
		'colsample_bytree': 0.85,
    'alpha': 0.1, 
    'lamnbda': 0.3                                               
}

model = xgb.train( params, dtrain, 500, evals=wlist, verbose_eval=20, early_stopping_rounds=100)
# Out:
# [0]	train-mae:205539	eval-mae:183100
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# [20]	train-mae:73715.8	eval-mae:58680
# [40]	train-mae:26501.8	eval-mae:15157.3
# [60]	train-mae:10651.4	eval-mae:7356.73
# [80]	train-mae:7611.32	eval-mae:8261.62
# [100]	train-mae:7168.83	eval-mae:8605.63
# [120]	train-mae:7032.49	eval-mae:8714.84
# [140]	train-mae:6967.71	eval-mae:8661.84
# Stopping. Best iteration:
# [58]	train-mae:11426.3	eval-mae:7311.9

# %%
xgb_train_pred = (model.predict(d_train))
xgb_val_pred = (model.predict(d_val))

# %%
valid =val_y.values

import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
plt.plot(valid, label='true')
plt.plot(xgb_val_pred , label='pred')
plt.legend()
plt.show()

# %%
from sklearn import metrics
print("MAE:", metrics.mean_absolute_error(valid, xgb_val_pred))
# Out:
# MAE: 8546.814710822968

# %%
xgb_prediction_df = pd.DataFrame(val_df['체결 날짜'], columns=['체결 날짜'])
xgb_prediction_df['거래 가격'] = val_df['거래 가격']
xgb_prediction_df['예측'] = xgb_val_pred
xgb_prediction_df
# Out:
#            체결 날짜   거래 가격             예측
# 16111 2022-06-15  279000  266713.843750
# 16112 2022-06-15  278000  266713.843750
# 16113 2022-06-15  277000  266713.843750
# 16114 2022-06-15  274000  266713.843750
# 16115 2022-06-15  271000  266713.843750
# ...          ...     ...            ...
# 20608 2022-06-30  243000  241100.390625
# 20609 2022-06-30  244000  241100.390625
# 20610 2022-06-30  233000  217119.078125
# 20611 2022-06-30  276000  269346.593750
# 20612 2022-06-30  274000  269346.593750
#
# [4502 rows x 3 columns]

# %%
xgb_prediction_df = pd.DataFrame(val_df['체결 날짜'], columns=['체결 날짜'])
xgb_prediction_df['거래 가격'] = val_df['거래 가격']
xgb_prediction_df['예측'] = xgb_val_pred
xgb_prediction_df  #다른 신발 모으던지, 시계열로 가던지
# Out:
#            체결 날짜   거래 가격             예측
# 16111 2022-06-15  279000  254818.109375
# 16112 2022-06-15  278000  254818.109375
# 16113 2022-06-15  277000  254818.109375
# 16114 2022-06-15  274000  254818.109375
# 16115 2022-06-15  271000  254818.109375
# ...          ...     ...            ...
# 20608 2022-06-30  243000  202437.609375
# 20609 2022-06-30  244000  202437.609375
# 20610 2022-06-30  233000  202437.609375
# 20611 2022-06-30  276000  263328.812500
# 20612 2022-06-30  274000  263328.812500
#
# [4502 rows x 3 columns]

# %%
test_x = test[features]
test_X = xgb.DMatrix(test_x)

pred = model.predict(test_X)

# %% [markdown]
# ### LGBM

# %%
# 중요도 top들로만 
train_x = train_df[data.index.values]
val_x = val_df[data.index.values]

# %%
train_y = train_df['targetprice']
val_y = val_df['targetprice']

# %%
# 파라미터 !!! 
params = {
    'objective': 'regression',
'boosting_type': ['gbdt'],
 'learning_rate': 0.02,
 'max_depth': 4,
 'metric': 'mae',
 'n_estimators': 10000,
 'random_state': 42,
'num_leaves': 506, 'min_child_samples': 99, 'reg_alpha': 0.1585234458533463, 'reg_lambda': 0.6535395893689313, 'colsample_bytree': 1.0, 'subsample': 0.4}

# %%
import lightgbm as lgb
ds_train = lgb.Dataset(train_x, train_y)
ds_val = lgb.Dataset(val_x, val_y)


lgbm_model = lgb.train(params, ds_train, 10000, ds_val, early_stopping_rounds=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [5003]	valid_0's l1: 4340.65
# [5004]	valid_0's l1: 4340.56
# [5005]	valid_0's l1: 4340.39
# [5006]	valid_0's l1: 4340.36
# [5007]	valid_0's l1: 4340.13
# [5008]	valid_0's l1: 4339.99
# [5009]	valid_0's l1: 4339.71
# [5010]	valid_0's l1: 4339.33
# [5011]	valid_0's l1: 4339.13
# [5012]	valid_0's l1: 4338.73
# [5013]	valid_0's l1: 4338.53
# [5014]	valid_0's l1: 4338.39
# [5015]	valid_0's l1: 4337.8
# [5016]	valid_0's l1: 4337.79
# [5017]	valid_0's l1: 4337.51
# [5018]	valid_0's l1: 4337.31
# [5019]	valid_0's l1: 4336.82
# [5020]	valid_0's l1: 4336.34
# [5021]	valid_0's l1: 4335.87
# [5022]	valid_0's l1: 4335.38
# [5023]	valid_0's l1: 4335.03
# [5024]	valid_0's l1: 4334.86
# [5025]	valid_0's l1: 4334.6
# [5026]	valid_0's l1: 4334.41
# [5027]	valid_0's l1: 4334.11
# [9962]	valid_0's l1: 3499.92
# [9963]	valid_0's l1: 3499.89
# [9964]	valid_0's l1: 3499.8
# [9965]	valid_0's l1: 3499.77
# [9966]	valid_0's l1: 3499.75
# [9967]	valid_0's l1: 3499.69
# [9968]	valid_0's l1: 3499.66
# [9969]	valid_0's l1: 3499.63
# [9970]	valid_0's l1: 3499.6
# [9971]	valid_0's l1: 3499.48
# [9972]	valid_0's l1: 3499.37
# [9973]	valid_0's l1: 3499.43
# [9974]	valid_0's l1: 3499.37
# [9975]	valid_0's l1: 3499.35
# [9976]	valid_0's l1: 3499.32
# [9977]	valid_0's l1: 3499.31
# [9978]	valid_0's l1: 3499.19
# [9979]	valid_0's l1: 3499.16
# [9980]	valid_0's l1: 3498.99
# [9981]	valid_0's l1: 3498.88
# [9982]	valid_0's l1: 3498.69
# [9983]	valid_0's l1: 3498.56
# [9984]	valid_0's l1: 3498.47
# [9985]	valid_0's l1: 3498.41
# [9986]	valid_0's l1: 3498.52
# [9987]	valid_0's l1: 3498.44
# [9988]	valid_0's l1: 3498.31
# [9989]	valid_0's l1: 3498.29
# [9990]	valid_0's l1: 3498.15
# [9991]	valid_0's l1: 3498.12
# [9992]	valid_0's l1: 3498.18
# [9993]	valid_0's l1: 3498.1
# [9994]	valid_0's l1: 3498.09
# [9995]	valid_0's l1: 3498.2
# [9996]	valid_0's l1: 3498.1
# [9997]	valid_0's l1: 3498.07
# [9998]	valid_0's l1: 3498.12
# [9999]	valid_0's l1: 3497.85
# [10000]	valid_0's l1: 3497.82
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's l1: 3497.82

# %%
y_val_lgbm_pred = lgbm_model.predict(val_x)

# %%
valid =val_y.values

import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
plt.plot(valid, label='true')
plt.plot(y_val_lgbm_pred , label='pred')
plt.legend()
plt.show()

# %%
from sklearn import metrics
print("MAE:", metrics.mean_absolute_error(valid, y_val_lgbm_pred))
print('MSE:', metrics.mean_squared_error(valid, y_val_lgbm_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(valid, y_val_lgbm_pred))) #더 안좋음
# Out:
# MAE: 3497.8208589238284
# MSE: 61786233.61207187
# RMSE: 7860.421974173643

# %%
lgm_prediction_df = pd.DataFrame(val_df['date'], columns=['date'])
lgm_prediction_df['targetprice'] = val_df['targetprice']
lgm_prediction_df['pred'] =y_val_lgbm_pred
lgm_prediction_df
# Out:
#             date    targetprice           pred
# 0     2022-03-30  136755.555556  135955.515253
# 1     2022-03-30  136793.548387  135955.515253
# 2     2022-03-30  137238.709677  135955.515253
# 3     2022-03-30  137717.791411  135955.515253
# 4     2022-03-30  137429.577465  135955.515253
# ...          ...            ...            ...
# 6894  2022-06-29  754529.411765  722890.253085
# 6895  2022-06-29  782285.714286  749873.862610
# 6896  2022-06-30  711428.571429  720648.826595
# 6897  2022-06-30  754529.411765  727432.548690
# 6898  2022-07-01  711428.571429  716565.240921
#
# [6899 rows x 3 columns]

# %%
np.mean(lgm_prediction_df['targetprice']-lgm_prediction_df['pred']) #200원 차이
# Out:
# -273.34550189643005
